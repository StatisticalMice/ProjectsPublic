# %%
# Display information about the environment
version
# Out:
#                _
# platform       x86_64-apple-darwin19.6.0
# arch           x86_64
# os             darwin19.6.0
# system         x86_64, darwin19.6.0
# status
# major          4
# minor          0.3
# year           2020
# month          10
# day            10
# svn rev        79318
# language       R
# version.string R version 4.0.3 (2020-10-10)
# nickname       Bunny-Wunnies Freak Out

# %%
Sys.getenv('R_MAX_VSIZE')
# Out:
# [1] "32000000000"

# %%
require(tictoc)
tic()
# Out:
# Loading required package: tictoc

# %%
require(tibble)
require(dplyr)
require(microbenchmark)
# Out:
# Loading required package: tibble
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: microbenchmark

# %%
N = 10^8

# %%
df = tibble(data = rnorm(N)) %>%
    mutate(sma = lag(data, 10))

# %%
df
# Out:
#           data         sma
# 1         -0.40079106           NA
# 2         -0.33611331           NA
# 3         -1.18532541           NA
# 4         -0.70857256           NA
# 5          0.51383812           NA
# 6         -0.10345540           NA
# 7         -0.08440493           NA
# 8         -1.22077160           NA
# 9         -1.75516987           NA
# 10        -0.26261764           NA
# 11         0.24712452  -0.40079106
# 12        -0.50411096  -0.33611331
# 13         0.05604112  -1.18532541
# 14        -0.12235097  -0.70857256
# 15         0.14857183   0.51383812
# 16        -0.02968845  -0.10345540
# 17         0.09245157  -0.08440493
# 18        -1.07005627  -1.22077160
# 19         0.16776803  -1.75516987
# 20        -0.65214461  -0.26261764
# 21        -0.63226364   0.24712452
# 22         1.97328574  -0.50411096
# 23         0.59282008   0.05604112
# 24         1.68082630  -0.12235097
# 25        -1.04283447   0.14857183
# 26        -1.10660027  -0.02968845
# 27         0.40866753   0.09245157
# 28         2.62013724  -1.07005627
# 29         0.42744857   0.16776803
# 30         0.44975859  -0.65214461
# ⋮         ⋮            ⋮
# 99999971  -1.915103533 -0.005517276
# 99999972  -0.770036215 -0.182715882
# 99999973  -0.537804646 -0.752675505
# 99999974  -1.881259777  1.054468047
# 99999975   1.013003977  0.868315639
# 99999976   0.899634508 -0.690623817
# 99999977  -0.695578442  0.106459291
# 99999978  -1.171944310  0.486911872
# 99999979   0.329587531 -0.667121018
# 99999980   0.290631375 -1.465566772
# 99999981  -0.727720507 -1.915103533
# 99999982   3.046978331 -0.770036215
# 99999983   1.080123149 -0.537804646
# 99999984   0.885634638 -1.881259777
# 99999985   0.440280953  1.013003977
# 99999986   0.760520543  0.899634508
# 99999987   0.703957345 -0.695578442
# 99999988   0.372409305 -1.171944310
# 99999989   0.093339505  0.329587531
# 99999990  -0.255402554  0.290631375
# 99999991   0.832128298 -0.727720507
# 99999992   0.502328958  3.046978331
# 99999993  -2.097048858  1.080123149
# 99999994  -0.009742226  0.885634638
# 99999995  -1.140811599  0.440280953
# 99999996   2.437132650  0.760520543
# 99999997  -1.278796757  0.703957345
# 99999998  -0.760751677  0.372409305
# 99999999   1.239156292  0.093339505
# 100000000 -1.121515167 -0.255402554

# %%
toc()
# Out:
# 5.899 sec elapsed

# %%
res = microbenchmark(rnorm(N), times=10)

# %%
print(res)
# Out:
# Unit: seconds
#      expr      min       lq     mean   median       uq      max neval
#  rnorm(N) 4.061612 4.291262 4.473564 4.488627 4.690355 4.809444    10

# %%
res2 = microbenchmark(mutate(df, sma = lag(data, 10)), times=10)

# %%
print(res2)
# Out:
# Unit: seconds
#                             expr      min       lq     mean   median       uq
#  mutate(df, sma = lag(data, 10)) 1.000762 1.256936 1.266624 1.279547 1.344235
#       max neval
#  1.407653    10
